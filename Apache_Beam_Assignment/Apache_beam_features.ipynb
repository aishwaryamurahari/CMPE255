# %% [markdown]
# Apache Beam is an open-source, unified programming model for defining and executing data processing pipelines. It is particularly useful for organizations dealing with both batch and streaming data, or those looking for flexibility in their data processing infrastructure. It allows developers to write data processing logic once and run it on various execution engines, providing portability and future-proofing for data pipelines.

# %% [markdown]
# ### Step 1: Install Apache Beam
# First, install the Apache Beam Python SDK.

# %%
# !pip install apache-beam[gcp]
# Out:
# Collecting apache-beam[gcp]
#   Downloading apache_beam-2.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting crcmod<2.0,>=1.7 (from apache-beam[gcp])
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4,>=3.9.7 (from apache-beam[gcp])
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 961.7 kB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam[gcp])
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam[gcp])
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam[gcp])
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (1.64.1)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam[gcp])
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (4.23.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (3.3.0)
# Requirement already satisfied: numpy<1.27.0,>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (1.26.4)
# Collecting objsize<0.8.0,>=0.6.1 (from apache-beam[gcp])
#   Downloading objsize-0.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (24.1)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam[gcp])
#   Downloading pymongo-4.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (1.24.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (3.20.3)
# Collecting pydot<2,>=1.2.0 (from apache-beam[gcp])
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2024.2)
# Collecting redis<6,>=5.0.0 (from apache-beam[gcp])
#   Downloading redis-5.1.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2024.9.11)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (4.12.2)
# Collecting zstandard<1,>=0.18.0 (from apache-beam[gcp])
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pyarrow<17.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (0.6)
# Collecting js2py<1,>=0.74 (from apache-beam[gcp])
#   Downloading Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (5.5.0)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.19.2)
# Collecting google-apitools<0.5.32,>=0.5.31 (from apache-beam[gcp])
#   Downloading google-apitools-0.5.31.tar.gz (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.19.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.23.1)
# Collecting google-cloud-pubsublite<2,>=1.2.0 (from apache-beam[gcp])
#   Downloading google_cloud_pubsublite-1.11.1-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-storage<3,>=2.18.2 (from apache-beam[gcp])
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (3.25.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.26.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.4.1)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.26.0)
# Collecting google-cloud-spanner<4,>=3.0.0 (from apache-beam[gcp])
#   Downloading google_cloud_spanner-3.49.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting google-cloud-dlp<4,>=3.0.0 (from apache-beam[gcp])
#   Downloading google_cloud_dlp-3.23.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (2.13.4)
# Collecting google-cloud-videointelligence<3,>=2.0 (from apache-beam[gcp])
#   Downloading google_cloud_videointelligence-2.13.5-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting google-cloud-vision<4,>=2 (from apache-beam[gcp])
#   Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting google-cloud-recommendations-ai<0.11.0,>=0.1.0 (from apache-beam[gcp])
#   Downloading google_cloud_recommendations_ai-0.10.12-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]) (1.68.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]) (1.65.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (4.1.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]) (4.9)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (1.12.5)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.0.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.16)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]) (0.13.1)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]) (1.48.2)
# Collecting overrides<8.0.0,>=6.0.1 (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp])
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]) (0.5.1)
# Collecting grpc-interceptor>=0.15.4 (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp])
#   Downloading grpc_interceptor-0.15.4-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3,>=2.18.2->apache-beam[gcp]) (1.6.0)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]) (3.1.4)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]) (5.2)
# Collecting pyjsparser>=2.5.1 (from js2py<1,>=0.74->apache-beam[gcp])
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]) (0.20.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam[gcp])
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6,>=5.0.0->apache-beam[gcp]) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]) (2024.8.30)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]) (2.23.4)
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.1 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading google_cloud_dlp-3.23.0-py2.py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.8/193.8 kB 10.7 MB/s eta 0:00:00
# Downloading google_cloud_pubsublite-1.11.1-py2.py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 14.5 MB/s eta 0:00:00
# Downloading google_cloud_recommendations_ai-0.10.12-py2.py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.7/184.7 kB 9.7 MB/s eta 0:00:00
# Downloading google_cloud_spanner-3.49.1-py2.py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.7/402.7 kB 19.9 MB/s eta 0:00:00
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 7.9 MB/s eta 0:00:00
# Downloading google_cloud_videointelligence-2.13.5-py2.py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.0/245.0 kB 15.1 MB/s eta 0:00:00
# Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.5/467.5 kB 25.7 MB/s eta 0:00:00
# Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.5 MB/s eta 0:00:00
# Downloading objsize-0.7.0-py3-none-any.whl (11 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.5 MB/s eta 0:00:00
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading pymongo-4.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.9 MB/s eta 0:00:00
# Downloading redis-5.1.0-py3-none-any.whl (261 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 13.8 MB/s eta 0:00:00
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 55.6 MB/s eta 0:00:00
# Downloading apache_beam-2.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 54.2 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 14.8 MB/s eta 0:00:00
# Downloading grpc_interceptor-0.15.4-py3-none-any.whl (20 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Building wheels for collected packages: crcmod, dill, google-apitools, hdfs, pyjsparser, docopt
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31405 sha256=88bbf261ed1d830bbe02d3096877000d583e69c29f800b6342cc17df1295ba0b
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=7cc20d62bc237564754e143aeb3cc9863d029a731a1c7f416ea581d80dd4718d
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for google-apitools (setup.py) ... done
#   Created wheel for google-apitools: filename=google_apitools-0.5.31-py3-none-any.whl size=131014 sha256=e87636e88b23d1fa2396c84daed551c81b294e293c3893273e70067adc86d931
#   Stored in directory: /root/.cache/pip/wheels/04/b7/e0/9712f8c23a5da3d9d16fb88216b897bf60e85b12f5470f26ee
#   Building wheel for hdfs (setup.py) ... done
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34325 sha256=49c636a3fcc653a877a043f0ca777a681407730ef0b132175ed7e77be8523d65
#   Stored in directory: /root/.cache/pip/wheels/e5/8d/b6/99c1c0a3ac5788c866b0ecd3f48b0134a5910e6ed26011800b
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25983 sha256=1eee0ee80de602529078deb2e6ba4dc797f244c51769adbbd050d2645cfcb00a
#   Stored in directory: /root/.cache/pip/wheels/5e/81/26/5956478df303e2bf5a85a5df595bb307bd25948a4bab69f7c7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=dc01f23c678fd692a0048bcf392bbfeb93b206bcb74b3580a5df7a5093f51f80
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built crcmod dill google-apitools hdfs pyjsparser docopt
# Installing collected packages: pyjsparser, docopt, crcmod, zstandard, redis, pydot, overrides, orjson, objsize, js2py, grpc-interceptor, fasteners, fastavro, dnspython, dill, pymongo, hdfs, google-apitools, apache-beam, google-cloud-vision, google-cloud-videointelligence, google-cloud-storage, google-cloud-spanner, google-cloud-recommendations-ai, google-cloud-dlp, google-cloud-pubsublite
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.2
#     Uninstalling pydot-3.0.2:
#       Successfully uninstalled pydot-3.0.2
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.8.0
#     Uninstalling google-cloud-storage-2.8.0:
#       Successfully uninstalled google-cloud-storage-2.8.0
# Successfully installed apache-beam-2.59.0 crcmod-1.7 dill-0.3.1.1 dnspython-2.6.1 docopt-0.6.2 fastavro-1.9.7 fasteners-0.19 google-apitools-0.5.31 google-cloud-dlp-3.23.0 google-cloud-pubsublite-1.11.1 google-cloud-recommendations-ai-0.10.12 google-cloud-spanner-3.49.1 google-cloud-storage-2.18.2 google-cloud-videointelligence-2.13.5 google-cloud-vision-3.7.4 grpc-interceptor-0.15.4 hdfs-2.7.3 js2py-0.74 objsize-0.7.0 orjson-3.10.7 overrides-7.7.0 pydot-1.4.2 pyjsparser-2.7.1 pymongo-4.10.0 redis-5.1.0 zstandard-0.23.0

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d altruistdelhite04/loan-prediction-problem-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset
# License(s): unknown
# Downloading loan-prediction-problem-dataset.zip to /content
#   0% 0.00/12.6k [00:00<?, ?B/s]
# 100% 12.6k/12.6k [00:00<00:00, 24.3MB/s]

# %%
# !unzip loan-prediction-problem-dataset.zip
# Out:
# Archive:  loan-prediction-problem-dataset.zip
#   inflating: test_Y3wMUE5_7gLdaTN.csv
#   inflating: train_u6lujuX_CVtuZ9i.csv

# %% [markdown]
# ### Step 2: Set Up the Apache Beam Pipeline
# We'll start by importing the necessary modules and creating a simple pipeline. Here's how to structure the basic components and include composite transforms, windowing, and ParDo.

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
import csv
import time
from apache_beam.transforms import window

# Define PipelineOptions
options = PipelineOptions()

# Composite Transform Example: Split and Extract Fields
class ExtractFields(beam.PTransform):
    def expand(self, pcoll):
        return (
            pcoll
            | 'Split CSV' >> beam.ParDo(SplitCSVRow())
            | 'Extract Loan Fields' >> beam.Map(lambda fields: {
                'Loan_ID': fields[0],
                'Gender': fields[1],
                'Married': fields[2],
                'ApplicantIncome': fields[5],
                'LoanAmount': fields[8],
                'Loan_Status': fields[12]
            })
        )

# ParDo Example: Custom DoFn to Split CSV Rows
class SplitCSVRow(beam.DoFn):
    def process(self, element):
        # Split each line into CSV columns
        reader = csv.reader([element])
        for row in reader:
            yield row

# ParDo Example: Custom DoFn to Print Elements
class PrintElement(beam.DoFn):
    def process(self, element):
        print(element)
        yield element

# Function to run the pipeline
def run_pipeline():
    with beam.Pipeline(options=options) as p:
        # Read the Kaggle CSV file
        csv_data = p | 'Read CSV' >> beam.io.ReadFromText('train_u6lujuX_CVtuZ9i.csv', skip_header_lines=1)

        # Composite Transform: Extract fields from CSV
        extracted_data = csv_data | 'Extract Loan Data' >> ExtractFields()

        # ParDo: Print the data
        extracted_data | 'Print Extracted Data' >> beam.ParDo(PrintElement())

        # Windowing Example: Apply fixed windowing of 10 seconds
        windowed_data = (
            extracted_data
            | 'Apply Fixed Windowing' >> beam.WindowInto(window.FixedWindows(10))
        )

        # Trigger Example: After processing time of 5 seconds
        triggered_data = windowed_data | 'Apply Trigger' >> beam.WindowInto(
            window.FixedWindows(10),
            trigger=beam.trigger.AfterProcessingTime(5),
            accumulation_mode=beam.trigger.AccumulationMode.DISCARDING
        )

        # Write results to a file
        triggered_data | 'Write to Output' >> beam.io.WriteToText('loan_output.txt')

run_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']
# {'Loan_ID': 'LP001002', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001003', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '128', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001005', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '66', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001006', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001008', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '141', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001011', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '267', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001013', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '95', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001014', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '158', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001018', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '168', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001020', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '349', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001024', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001027', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '109', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001028', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '200', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001029', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '114', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001030', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '17', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001032', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '125', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001034', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001036', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '76', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001038', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '133', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001041', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '115', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001043', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '104', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001046', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '315', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001047', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '116', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001050', 'Gender': '', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '112', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001052', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '151', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001066', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '191', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001068', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '122', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001073', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001086', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '35', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001087', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001091', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '201', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001095', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '74', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001097', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '106', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001098', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '114', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001100', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '320', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001106', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001109', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001112', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '144', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001114', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '184', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001116', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001119', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '80', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001120', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '47', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001123', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '75', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001131', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '134', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001136', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '96', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001137', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '88', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001138', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '44', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001144', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '144', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001146', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001151', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '144', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001155', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001157', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001164', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '112', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001179', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '134', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001186', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '286', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001194', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '97', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001195', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '96', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001197', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '135', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001198', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '180', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001199', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '144', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001205', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001206', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '99', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001207', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '165', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001213', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001222', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '116', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001225', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '258', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001228', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '126', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001233', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '312', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001238', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '125', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001241', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '136', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001243', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '172', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001245', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '97', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001248', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '81', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001250', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '95', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001253', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '187', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001255', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '113', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001256', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '176', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001259', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '110', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001263', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '180', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001264', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '130', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001265', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '111', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001266', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001267', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '167', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001273', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '265', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001275', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '50', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001279', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '136', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001280', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '99', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001282', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '104', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001289', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '210', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001310', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '175', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001316', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '131', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001318', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '188', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001319', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '81', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001322', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '122', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001325', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '25', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001326', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001327', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '137', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001333', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '50', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001334', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '115', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001343', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '131', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001345', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '133', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001349', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '151', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001350', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001356', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001357', 'Gender': 'Male', 'Married': '', 'ApplicantIncome': 'No', 'LoanAmount': '160', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001367', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001369', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '225', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001370', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '120', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001379', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '216', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001384', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '94', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001385', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '136', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001387', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '139', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001391', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '152', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001392', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001398', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '118', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001401', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '185', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001404', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '154', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001405', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '85', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001421', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '175', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001422', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '259', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001426', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '180', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001430', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '44', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001431', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '137', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001432', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '81', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001439', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '194', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001443', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '93', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001448', 'Gender': '', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '370', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001449', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001451', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '160', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001465', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '182', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001469', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '650', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001473', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '74', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001478', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001482', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '25', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001487', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '102', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001488', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '290', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001489', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '84', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001491', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '88', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP
 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002603', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '113', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002606', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002615', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '208', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002618', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '138', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002619', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '124', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002622', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '243', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002624', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '480', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002625', 'Gender': '', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '96', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002626', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '188', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002634', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '40', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002637', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002640', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '250', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002643', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '148', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002648', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002652', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '311', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002659', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '150', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002670', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '113', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002682', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '123', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002683', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '185', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002684', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '95', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002689', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '45', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002690', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '55', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002692', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002693', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '480', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002697', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002699', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '400', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002705', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002706', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '161', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002714', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '94', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002716', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '130', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002717', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '216', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002720', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002723', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002729', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '196', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002731', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '125', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002732', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '126', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002734', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '324', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002738', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '107', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002739', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '66', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002740', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '157', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002741', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '140', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002743', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '99', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002753', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '95', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002755', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '128', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002757', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '102', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002767', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '155', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002768', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '80', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002772', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '145', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002776', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '103', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002777', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002778', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002784', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002785', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '158', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002788', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '181', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002789', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '132', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002792', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '26', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002794', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '84', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002795', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '260', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002798', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '162', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002804', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '182', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002807', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '108', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002813', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '600', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002820', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '211', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002821', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '132', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002832', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '258', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002833', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002836', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002837', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '123', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002840', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '9', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002841', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '104', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002842', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '186', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002847', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '165', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002855', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '275', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002862', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '187', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002863', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '150', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002868', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '108', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002872', 'Gender': '', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '136', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002874', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002877', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '107', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002888', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '161', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002892', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '205', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002893', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '90', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002894', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '36', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002898', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '61', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002911', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '146', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002912', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '172', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002916', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '104', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002917', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002925', 'Gender': '', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '94', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002926', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '106', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002928', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '56', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002931', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '205', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002933', 'Gender': '', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '292', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002936', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '142', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002938', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '260', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002940', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002941', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '187', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002943', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '88', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002945', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '180', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002948', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '192', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002949', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '350', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002950', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '155', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002953', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '128', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002958', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '172', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002959', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '496', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002960', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP002961', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '173', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002964', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '157', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002974', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '108', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002978', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '71', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002979', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '40', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002983', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '253', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002984', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '187', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002990', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '133', 'Loan_Status': 'N'}

# %% [markdown]
# Explanation of the Features
# Composite Transform:
#
# 1. The ExtractFields class is a composite transform that applies multiple transforms, including SplitCSVRow (which splits the CSV row into fields) and a Map function (which extracts specific columns such as Loan_ID, ApplicantIncome, etc.).
# Pipeline I/O:
#
# 2. The beam.io.ReadFromText() function reads the Kaggle CSV file (train.csv).
# The beam.io.WriteToText() function writes the output to a text file (loan_output.txt).
# ParDo:
#
# 3. The SplitCSVRow class demonstrates a ParDo operation that processes each element (CSV row) by splitting it into individual fields.
# Another ParDo, PrintElement, simply prints the extracted fields for demonstration.
# Windowing:
#
# 4. The beam.WindowInto(window.FixedWindows(10)) applies fixed-time windowing, which groups elements that arrive within 10-second intervals.
# Triggers:
#
# 5. A trigger is applied using beam.WindowInto() with a trigger condition AfterProcessingTime(5) that emits the results 5 seconds after processing begins.

# %% [markdown]
# ### Step 3: Check the Output
# You can check the output file loan_output.txt

# %%
# !cat loan_output.txt-00000-of-00001
# Out:
# {'Loan_ID': 'LP001002', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001003', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '128', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001005', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '66', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001006', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001008', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '141', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001011', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '267', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001013', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '95', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001014', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '158', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001018', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '168', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001020', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '349', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001024', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '70', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001027', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '109', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001028', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '200', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001029', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '114', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001030', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '17', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001032', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '125', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001034', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001036', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '76', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001038', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '133', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001041', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '115', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001043', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '104', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001046', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '315', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001047', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '116', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001050', 'Gender': '', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '112', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001052', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '151', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001066', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '191', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001068', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '122', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001073', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001086', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '35', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001087', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': '', 'LoanAmount': '120', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001091', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': '', 'LoanAmount': '201', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001095', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '74', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001097', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '106', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001098', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '114', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001100', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '320', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001106', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001109', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '100', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001112', 'Gender': 'Female', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '144', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001114', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '184', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001116', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '110', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001119', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '80', 'Loan_Status': 'N'}
# {'Loan_ID': 'LP001120', 'Gender': 'Male', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '47', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001123', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '75', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001131', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '134', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001136', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'Yes', 'LoanAmount': '96', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001137', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '88', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP001138', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '44', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP
 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '157', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002974', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '108', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002978', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'No', 'LoanAmount': '71', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002979', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '40', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002983', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '253', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002984', 'Gender': 'Male', 'Married': 'Yes', 'ApplicantIncome': 'No', 'LoanAmount': '187', 'Loan_Status': 'Y'}
# {'Loan_ID': 'LP002990', 'Gender': 'Female', 'Married': 'No', 'ApplicantIncome': 'Yes', 'LoanAmount': '133', 'Loan_Status': 'N'}

# %% [markdown]
# There are several additional Apache Beam features that you can explore with your Kaggle dataset to enhance the complexity and flexibility of your data pipeline. Here are some key advanced features

# %% [markdown]
# ### GroupByKey and CoGroupByKey
# These transformations are useful for grouping or joining data. For example, if you have multiple datasets (like loan data and applicant demographic data), you can use GroupByKey to group data by a specific key (e.g., Loan_ID), or CoGroupByKey to join two datasets based on a common key.

# %% [markdown]
# Group Loan Data by Status :
# You can group loans by their Loan_Status to analyze them by categories like "Approved" or "Rejected".

# %%
def run_group_by_pipeline():
    with beam.Pipeline(options=options) as p:
        # Read CSV file
        csv_data = p | 'Read CSV' >> beam.io.ReadFromText('train_u6lujuX_CVtuZ9i.csv', skip_header_lines=1)

        # Extract Loan_ID and Loan_Status
        loan_data = (
            csv_data
            | 'Extract Loan Data' >> beam.ParDo(SplitCSVRow())
            | 'Key by Loan Status' >> beam.Map(lambda row: (row[12], row))  # Using Loan_Status as key
        )

        # Group by Loan_Status (Approved/Rejected)
        grouped_data = loan_data | 'Group by Loan Status' >> beam.GroupByKey()

        # Print grouped data
        grouped_data | 'Print Grouped Data' >> beam.Map(print)

run_group_by_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']
# ('Y', [['LP001002', 'Male', 'No', '0', 'Graduate', 'No', '5849', '0', '', '360', '1', 'Urban', 'Y'], ['LP001005', 'Male', 'Yes', '0', 'Graduate', 'Yes', '3000', '0', '66', '360', '1', 'Urban', 'Y'], ['LP001006', 'Male', 'Yes', '0', 'Not Graduate', 'No', '2583', '2358', '120', '360', '1', 'Urban', 'Y'], ['LP001008', 'Male', 'No', '0', 'Graduate', 'No', '6000', '0', '141', '360', '1', 'Urban', 'Y'], ['LP001011', 'Male', 'Yes', '2', 'Graduate', 'Yes', '5417', '4196', '267', '360', '1', 'Urban', 'Y'], ['LP001013', 'Male', 'Yes', '0', 'Not Graduate', 'No', '2333', '1516', '95', '360', '1', 'Urban', 'Y'], ['LP001018', 'Male', 'Yes', '2', 'Graduate', 'No', '4006', '1526', '168', '360', '1', 'Urban', 'Y'], ['LP001024', 'Male', 'Yes', '2', 'Graduate', 'No', '3200', '700', '70', '360', '1', 'Urban', 'Y'], ['LP001027', 'Male', 'Yes', '2', 'Graduate', '', '2500', '1840', '109', '360', '1', 'Urban', 'Y'], ['LP001028', 'Male', 'Yes', '2', 'Graduate', 'No', '3073', '8106', '200', '360', '1', 'Urban', 'Y'], ['LP001030', 'Male', 'Yes', '2', 'Graduate', 'No', '1299', '1086', '17', '120', '1', 'Urban', 'Y'], ['LP001032', 'Male', 'No', '0', 'Graduate', 'No', '4950', '0', '125', '360', '1', 'Urban', 'Y'], ['LP001034', 'Male', 'No', '1', 'Not Graduate', 'No', '3596', '0', '100', '240', '', 'Urban', 'Y'], ['LP001041', 'Male', 'Yes', '0', 'Graduate', '', '2600', '3500', '115', '', '1', 'Urban', 'Y'], ['LP001046', 'Male', 'Yes', '1', 'Graduate', 'No', '5955', '5625', '315', '360', '1', 'Urban', 'Y'], ['LP001066', 'Male', 'Yes', '0', 'Graduate', 'Yes', '9560', '0', '191', '360', '1', 'Semiurban', 'Y'], ['LP001068', 'Male', 'Yes', '0', 'Graduate', 'No', '2799', '2253', '122', '360', '1', 'Semiurban', 'Y'], ['LP001073', 'Male', 'Yes', '2', 'Not Graduate', 'No', '4226', '1040', '110', '360', '1', 'Urban', 'Y'], ['LP001087', 'Female', 'No', '2', 'Graduate', '', '3750', '2083', '120', '360', '1', 'Semiurban', 'Y'], ['LP001098', 'Male', 'Yes', '0', 'Graduate', 'No', '3500', '1667', '114', '360', '1', 'Semiurban', 'Y'], ['LP001106', 'Male', 'Yes', '0', 'Graduate', 'No', '2275', '2067', '', '360', '1', 'Urban', 'Y'], ['LP001112', 'Female', 'Yes', '0', 'Graduate', 'No', '3667', '1459', '144', '360', '1', 'Semiurban', 'Y'], ['LP001114', 'Male', 'No', '0', 'Graduate', 'No', '4166', '7210', '184', '360', '1', 'Urban', 'Y'], ['LP001116', 'Male', 'No', '0', 'Not Graduate', 'No', '3748', '1668', '110', '360', '1', 'Semiurban', 'Y'], ['LP001120', 'Male', 'No', '0', 'Graduate', 'No', '1800', '1213', '47', '360', '1', 'Urban', 'Y'], ['LP001123', 'Male', 'Yes', '0', 'Graduate', 'No', '2400', '0', '75', '360', '', 'Urban', 'Y'], ['LP001131', 'Male', 'Yes', '0', 'Graduate', 'No', '3941', '2336', '134', '360', '1', 'Semiurban', 'Y'], ['LP001136', 'Male', 'Yes', '0', 'Not Graduate', 'Yes', '4695', '0', '96', '', '1', 'Urban', 'Y'], ['LP001137', 'Female', 'No', '0', 'Graduate', 'No', '3410', '0', '88', '', '1', 'Urban', 'Y'], ['LP001138', 'Male', 'Yes', '1', 'Graduate', 'No', '5649', '0', '44', '360', '1', 'Urban', 'Y'], ['LP001144', 'Male', 'Yes', '0', 'Graduate', 'No', '5821', '0', '144', '360', '1', 'Urban', 'Y'], ['LP001151', 'Female', 'No', '0', 'Graduate', 'No', '4000', '2275', '144', '360', '1', 'Semiurban', 'Y'], ['LP001155', 'Female', 'Yes', '0', 'Not Graduate', 'No', '1928', '1644', '100', '360', '1', 'Semiurban', 'Y'], ['LP001157', 'Female', 'No', '0', 'Graduate', 'No', '3086', '0', '120', '360', '1', 'Semiurban', 'Y'], ['LP001194', 'Male', 'Yes', '2', 'Graduate', 'No', '2708', '1167', '97', '360', '1', 'Semiurban', 'Y'], ['LP001195', 'Male', 'Yes', '0', 'Graduate', 'No', '2132', '1591', '96', '360', '1', 'Semiurban', 'Y'], ['LP001198', 'Male', 'Yes', '1', 'Graduate', 'No', '8080', '2250', '180', '360', '1', 'Urban', 'Y'], ['LP001199', 'Male', 'Yes', '2', 'Not Graduate', 'No', '3357', '2859', '144', '360', '1', 'Urban', 'Y'], ['LP001205', 'Male', 'Yes', '0', 'Graduate', 'No', '2500', '3796', '120', '360', '1', 'Urban', 'Y'], ['LP001206', 'Male', 'Yes', '3+', 'Gradu ...
# ('N', [['LP001003', 'Male', 'Yes', '1', 'Graduate', 'No', '4583', '1508', '128', '360', '1', 'Rural', 'N'], ['LP001014', 'Male', 'Yes', '3+', 'Graduate', 'No', '3036', '2504', '158', '360', '0', 'Semiurban', 'N'], ['LP001020', 'Male', 'Yes', '1', 'Graduate', 'No', '12841', '10968', '349', '360', '1', 'Semiurban', 'N'], ['LP001029', 'Male', 'No', '0', 'Graduate', 'No', '1853', '2840', '114', '360', '1', 'Rural', 'N'], ['LP001036', 'Female', 'No', '0', 'Graduate', 'No', '3510', '0', '76', '360', '0', 'Urban', 'N'], ['LP001038', 'Male', 'Yes', '0', 'Not Graduate', 'No', '4887', '0', '133', '360', '1', 'Rural', 'N'], ['LP001043', 'Male', 'Yes', '0', 'Not Graduate', 'No', '7660', '0', '104', '360', '0', 'Urban', 'N'], ['LP001047', 'Male', 'Yes', '0', 'Not Graduate', 'No', '2600', '1911', '116', '360', '0', 'Semiurban', 'N'], ['LP001050', '', 'Yes', '2', 'Not Graduate', 'No', '3365', '1917', '112', '360', '0', 'Rural', 'N'], ['LP001052', 'Male', 'Yes', '1', 'Graduate', '', '3717', '2925', '151', '360', '', 'Semiurban', 'N'], ['LP001086', 'Male', 'No', '0', 'Not Graduate', 'No', '1442', '0', '35', '360', '1', 'Urban', 'N'], ['LP001091', 'Male', 'Yes', '1', 'Graduate', '', '4166', '3369', '201', '360', '', 'Urban', 'N'], ['LP001095', 'Male', 'No', '0', 'Graduate', 'No', '3167', '0', '74', '360', '1', 'Urban', 'N'], ['LP001097', 'Male', 'No', '1', 'Graduate', 'Yes', '4692', '0', '106', '360', '1', 'Rural', 'N'], ['LP001100', 'Male', 'No', '3+', 'Graduate', 'No', '12500', '3000', '320', '360', '1', 'Rural', 'N'], ['LP001109', 'Male', 'Yes', '0', 'Graduate', 'No', '1828', '1330', '100', '', '0', 'Urban', 'N'], ['LP001119', 'Male', 'No', '0', 'Graduate', 'No', '3600', '0', '80', '360', '1', 'Urban', 'N'], ['LP001146', 'Female', 'Yes', '0', 'Graduate', 'No', '2645', '3440', '120', '360', '0', 'Urban', 'N'], ['LP001164', 'Female', 'No', '0', 'Graduate', 'No', '4230', '0', '112', '360', '1', 'Semiurban', 'N'], ['LP001179', 'Male', 'Yes', '2', 'Graduate', 'No', '4616', '0', '134', '360', '1', 'Urban', 'N'], ['LP001186', 'Female', 'Yes', '1', 'Graduate', 'Yes', '11500', '0', '286', '360', '0', 'Urban', 'N'], ['LP001197', 'Male', 'Yes', '0', 'Graduate', 'No', '3366', '2200', '135', '360', '1', 'Rural', 'N'], ['LP001207', 'Male', 'Yes', '0', 'Not Graduate', 'Yes', '2609', '3449', '165', '180', '0', 'Rural', 'N'], ['LP001213', 'Male', 'Yes', '1', 'Graduate', 'No', '4945', '0', '', '360', '0', 'Rural', 'N'], ['LP001222', 'Female', 'No', '0', 'Graduate', 'No', '4166', '0', '116', '360', '0', 'Semiurban', 'N'], ['LP001225', 'Male', 'Yes', '0', 'Graduate', 'No', '5726', '4595', '258', '360', '1', 'Semiurban', 'N'], ['LP001228', 'Male', 'No', '0', 'Not Graduate', 'No', '3200', '2254', '126', '180', '0', 'Urban', 'N'], ['LP001241', 'Female', 'No', '0', 'Graduate', 'No', '4300', '0', '136', '360', '0', 'Semiurban', 'N'], ['LP001250', 'Male', 'Yes', '3+', 'Not Graduate', 'No', '4755', '0', '95', '', '0', 'Semiurban', 'N'], ['LP001255', 'Male', 'No', '0', 'Graduate', 'No', '3750', '0', '113', '480', '1', 'Urban', 'N'], ['LP001256', 'Male', 'No', '0', 'Graduate', 'No', '3750', '4750', '176', '360', '1', 'Urban', 'N'], ['LP001259', 'Male', 'Yes', '1', 'Graduate', 'Yes', '1000', '3022', '110', '360', '1', 'Urban', 'N'], ['LP001263', 'Male', 'Yes', '3+', 'Graduate', 'No', '3167', '4000', '180', '300', '0', 'Semiurban', 'N'], ['LP001267', 'Female', 'Yes', '2', 'Graduate', 'No', '1378', '1881', '167', '360', '1', 'Urban', 'N'], ['LP001273', 'Male', 'Yes', '0', 'Graduate', 'No', '6000', '2250', '265', '360', '', 'Semiurban', 'N'], ['LP001326', 'Male', 'No', '0', 'Graduate', '', '6782', '0', '', '360', '', 'Urban', 'N'], ['LP001370', 'Male', 'No', '0', 'Not Graduate', '', '7333', '0', '120', '360', '1', 'Rural', 'N'], ['LP001379', 'Male', 'Yes', '2', 'Graduate', 'No', '3800', '3600', '216', '360', '0', 'Urban', 'N'], ['LP001391', 'Male', 'Yes', '0', 'Not Graduate', 'No', '3572', '4114', '152', '', '0', 'Rural', 'N'], ['LP001421', 'Male', 'Yes', '0', 'Graduate', ' ...

# %% [markdown]
# ### Side Inputs
# Side inputs allow you to pass additional data to a ParDo transformation. This is useful if you need to perform operations using external or constant data, such as applying reference data (e.g., loan interest rates or eligibility rules) to each record in your main dataset.

# %%
class FilterByIncome(beam.DoFn):
    def process(self, element, income_threshold):
        applicant_income = element['ApplicantIncome']
        try:
            applicant_income = int(applicant_income)
        except ValueError:
            applicant_income = 0  # or any other default value you want to use

        if applicant_income >= income_threshold:
            yield element

def run_side_input_pipeline():
    with beam.Pipeline(options=options) as p:
        # Read the CSV file
        csv_data = p | 'Read CSV' >> beam.io.ReadFromText('train_u6lujuX_CVtuZ9i.csv', skip_header_lines=1)

        # Extract loan data
        loan_data = csv_data | 'Extract Loan Data' >> ExtractFields()

        # Define an income threshold
        income_threshold = p | 'Create income threshold' >> beam.Create([5000])

        # Apply filter using Side Input
        filtered_data = loan_data | 'Filter by income' >> beam.ParDo(FilterByIncome(), beam.pvalue.AsSingleton(income_threshold))

        # Write filtered results to a file
        filtered_data | 'Write filtered data' >> beam.io.WriteToText('filtered_loan_output.txt')

run_side_input_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']

# %% [markdown]
# ### Combining Data with CombinePerKey
# You can use CombinePerKey to perform aggregations, such as summing, averaging, or counting data elements based on a specific key.

# %%
def run_combine_pipeline():
    with beam.Pipeline(options=options) as p:
        # Read the CSV file
        csv_data = p | 'Read CSV' >> beam.io.ReadFromText('train_u6lujuX_CVtuZ9i.csv', skip_header_lines=1)

        # Extract (Loan_Status, LoanAmount)
        loan_amounts = (
            csv_data
            | 'Extract Loan Amounts' >> beam.ParDo(SplitCSVRow())
            | 'Key by Loan Status' >> beam.Map(lambda row: (row[12], float(row[8] or 0)))  # (Loan_Status, LoanAmount)
        )

        # Sum LoanAmounts by Loan_Status
        total_loan_by_status = loan_amounts | 'Sum by Loan Status' >> beam.CombinePerKey(sum)

        # Write the result to an output file
        total_loan_by_status | 'Write Total Loan Amount' >> beam.io.WriteToText('total_loan_by_status.txt')

run_combine_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']

# %% [markdown]
# ### Sessions Windowing
# You can use session windowing when you're dealing with streaming data and want to group events that occur close to each other in time. This is ideal for datasets where user activity is bursty and happens in distinct sessions.

# %%
def run_sessions_windowing_pipeline():
    with beam.Pipeline(options=options) as p:
        # Simulate a stream of loan application events (timestamps added)
        loan_applications = p | 'Create Loan Applications' >> beam.Create([
            {'Loan_ID': 'LP001', 'Timestamp': 1},
            {'Loan_ID': 'LP002', 'Timestamp': 3},
            {'Loan_ID': 'LP001', 'Timestamp': 5},
            {'Loan_ID': 'LP003', 'Timestamp': 15}
        ])

        # Apply session windowing
        sessioned_data = (
            loan_applications
            | 'Session window' >> beam.WindowInto(window.Sessions(gap_size=10))
        )

        # Write the sessioned output to a file
        sessioned_data | 'Write Sessioned Output' >> beam.io.WriteToText('sessioned_output.txt')

run_sessions_windowing_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']

# %% [markdown]
# ### Side Outputs (Multi-output ParDo)
# You can use multi-output ParDo to produce multiple output streams from a single input stream, allowing you to split your data based on certain criteria.

# %%
class SplitLoanStatus(beam.DoFn):
    def process(self, element):
        if element['Loan_Status'] == 'Y':
            yield beam.pvalue.TaggedOutput('approved', element)
        else:
            yield beam.pvalue.TaggedOutput('rejected', element)

def run_split_output_pipeline():
    with beam.Pipeline(options=options) as p:
        loan_data = p | 'Read CSV' >> beam.io.ReadFromText('train_u6lujuX_CVtuZ9i.csv', skip_header_lines=1)

        extracted_data = loan_data | 'Extract Loan Data' >> ExtractFields()

        # Apply the multi-output ParDo
        split_result = extracted_data | 'Split by Loan Status' >> beam.ParDo(SplitLoanStatus()).with_outputs('approved', 'rejected')

        # Write approved loans
        split_result.approved | 'Write Approved Loans' >> beam.io.WriteToText('approved_loans.txt')

        # Write rejected loans
        split_result.rejected | 'Write Rejected Loans' >> beam.io.WriteToText('rejected_loans.txt')

run_split_output_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-b6cba0cd-7bda-4189-87fa-1f0bb38ba7c9.json']
